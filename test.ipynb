# %%
import json
# %matplotlib inline
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/sakthivelsabapathy/Desktop/python-projects/capital-one'

# %%
data=pd.read_json('./data/transactions.txt',lines=True)

# %%
data
# Out:
#         accountNumber accountOpenDate acqCountry  availableMoney  cardCVV  \
# 0           737265056      2015-03-14         US         5000.00      414
# 1           737265056      2015-03-14         US         5000.00      486
# 2           737265056      2015-03-14         US         5000.00      486
# 3           737265056      2015-03-14         US         5000.00      486
# 4           830329091      2015-08-06         US         5000.00      885
# 5           830329091      2015-08-06         US         5000.00      885
# 6           830329091      2015-08-06         US         5000.00      885
# 7           830329091      2015-08-06         US         5000.00      885
# 8           830329091      2015-08-06                    4990.63      885
# 9           830329091      2015-08-06         US         5000.00      885
# 10          830329091      2015-08-06         US         5000.00      885
# 11          830329091      2015-08-06         US         5000.00      885
# ...

# %%
data.columns.to_list
# Out:
# <bound method Index.tolist of Index([u'accountNumber', u'accountOpenDate', u'acqCountry', u'availableMoney',
#        u'cardCVV', u'cardLast4Digits', u'cardPresent', u'creditLimit',
#        u'currentBalance', u'currentExpDate', u'customerId',
#        u'dateOfLastAddressChange', u'echoBuffer', u'enteredCVV',
#        u'expirationDateKeyInMatch', u'isFraud', u'merchantCategoryCode',
#        u'merchantCity', u'merchantCountryCode', u'merchantName',
#        u'merchantState', u'merchantZip', u'posConditionCode', u'posEntryMode',
#        u'posOnPremises', u'recurringAuthInd', u'transactionAmount',
#        u'transactionDateTime', u'transactionType'],
#       dtype='object')>

# %%
print(data['merchantZip']).describe()
# Out:
# count     786363
# unique         1
# top
# freq      786363
# Name: merchantZip, dtype: object

# %%
data['merchantZip'].nunique()
# Out:
# 1

# %%
# check for null values in the various column. 
print("No. of Null Values inside data:", data.isnull().sum())
# Out:
# ('No. of Null Values inside data:', accountNumber               0
# accountOpenDate             0
# acqCountry                  0
# availableMoney              0
# cardCVV                     0
# cardLast4Digits             0
# cardPresent                 0
# creditLimit                 0
# currentBalance              0
# currentExpDate              0
# customerId                  0
# dateOfLastAddressChange     0
# echoBuffer                  0
# enteredCVV                  0
# expirationDateKeyInMatch    0
# isFraud                     0
# merchantCategoryCode        0
# merchantCity                0
# merchantCountryCode         0
# merchantName                0
# merchantState               0
# merchantZip                 0
# posConditionCode            0
# posEntryMode                0
# posOnPremises               0
# recurringAuthInd            0
# transactionAmount           0
# transactionDateTime         0
# transactionType             0
# dtype: int64)

# %%
#accountOpenDate,acqCountry,availableMoney,cardPresent,creditLimit,currentBalance,currentExpDate,dateOfLastAddressChange
#expirationDateKeyInMatch,isFraud,merchantCategoryCode,merchantCategoryCode,merchantCountryCode,merchantName
#'merchantState', u'merchantZip', u'posConditionCode', u'posEntryMode','posOnPremises', u'recurringAuthInd', u'transactionAmount'
#'transactionDateTime', u'transactionType'
